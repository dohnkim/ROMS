# %% [markdown]
# # 태풍 솔릭(Soulik) 모의를 위한<br/>HYCOM 자료로 ROMS 경계장(B.C.) 만들기

# %%
# Author: Dong-Hoon Kim (http://www.dhkim.info)

# %matplotlib inline
import matplotlib.pyplot as plt

import os, sys, subprocess
from datetime import datetime, timedelta

import numpy as np
from netCDF4 import Dataset #, num2date, date2num

import pyroms
import pyroms_toolbox

# load local tools
sys.path.append(os.path.abspath('../Tools/'))
from getGridHYCOM import getGridHYCOM
from remapBC import remapBC
from remapBCuv import remapBCuv

# %% [markdown]
# ## 0. HYCOM & ROMS 격자 정보 가져오기

# %%
# 실험명
expname = 'Soulik'; version = 'v4'

# 경계장 날짜 설정
date_beg = datetime(2018,8,21,0) # year, month, day, hour
date_end = datetime(2018,8,25,0) # year, month, day, hour
ymdh_beg = date_beg.strftime('%Y-%m-%dT%H:%M:%SZ')
ymdh_end = date_end.strftime('%Y-%m-%dT%H:%M:%SZ')

strideTime  = 1 # time resolution. ex) every 3hours * 1 = 3hours

src_name = 'HYCOM'
dst_name = expname # Note) must be same name in gridid.txt

src_grd = getGridHYCOM("./HYCOM/HYCOM4%s_ts3z_%s.nc4"%(expname,ymdh_beg),'water_temp',name=src_name)

# %env PYROMS_GRIDID_FILE=../Grid/gridid.txt
dst_grd = pyroms.grid.get_ROMS_grid(dst_name.upper()+version)

# make a direcotory for saving remapped ROMS files
if not os.path.isdir('ROMS'): os.makedirs('ROMS')
    
# remap weights file
wts_file = 'remap_weights_%s_to_%s_bilinear_t_to_rho.nc'%(src_name,dst_name)
# Out:
# env: PYROMS_GRIDID_FILE=../Grid/gridid.txt
# Assuming spherical is integer b'T' <class 'numpy.ma.core.MaskedArray'>
# Load geographical grid from file

# %% [markdown]
# ## 1. ROMS 격자의 SSH 경계장 만들기

# %%
dt = date_beg
while(dt <= date_end):
    ymdh = dt.strftime('%Y-%m-%dT%H:%M:%SZ')
    
    hycom_file = 'HYCOM/HYCOM4Soulik_ssh_%s.nc4'%ymdh
    roms_file = 'ROMS/ROMS4%s_ssh_%s.nc4'%(dst_name,ymdh)
    zeta = remapBC(hycom_file,'surf_el', wts_file, src_grd, dst_grd, roms_file, verbose=False)

    dt += timedelta(hours=3*strideTime)

# ---
dst_grd3z = pyroms.grid.get_ROMS_grid(dst_name.upper()+version, zeta=zeta)
# ---

with Dataset(roms_file,'r') as ncout:
    fig = plt.figure(figsize=(15,3))
    ax1 = fig.add_subplot(1,4,1); ax2 = fig.add_subplot(1,4,2)
    ax3 = fig.add_subplot(1,4,3); ax4 = fig.add_subplot(1,4,4)
    _=ax1.plot(ncout['zeta_south'][0,:]); _=ax2.plot(ncout['zeta_north'][0,:])
    _=ax3.plot(ncout['zeta_west'][0,:]);  _=ax4.plot(ncout['zeta_east'][0,:])
# Out:
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-21T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-22T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-23T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-24T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_ssh_2018-08-25T00:00:00Z.nc4
# Assuming spherical is integer b'T' <class 'numpy.ma.core.MaskedArray'>
# Load geographical grid from file

# %% [markdown]
# ## 2. ROMS 격자의 수온 경계장 만들기

# %%
dt = date_beg
while(dt <= date_end):
    ymdh = dt.strftime('%Y-%m-%dT%H:%M:%SZ')
    
    hycom_file = 'HYCOM/HYCOM4Soulik_ts3z_%s.nc4'%ymdh
    roms_file = 'ROMS/ROMS4%s_temp_%s.nc4'%(dst_name,ymdh)
    remapBC(hycom_file,'water_temp', wts_file, src_grd, dst_grd3z, roms_file, verbose=False)
    
    dt += timedelta(hours=3*strideTime)

with Dataset(roms_file,'r') as ncout:
    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(2,4,1); ax2 = fig.add_subplot(2,4,2)
    ax3 = fig.add_subplot(2,4,3); ax4 = fig.add_subplot(2,4,4)
    _=ax1.plot(ncout['temp_south'][0,-1,:]); _=ax2.plot(ncout['temp_north'][0,-1,:])
    _=ax3.plot(ncout['temp_west'][0,-1,:]);  _=ax4.plot(ncout['temp_east'][0,-1,:])
    ax5 = fig.add_subplot(2,4,5); ax6 = fig.add_subplot(2,4,6)
    ax7 = fig.add_subplot(2,4,7); ax8 = fig.add_subplot(2,4,8)
    _=ax5.imshow(ncout['temp_south'][0,:,:]); _=ax6.imshow(ncout['temp_north'][0,:,:])
    _=ax7.imshow(ncout['temp_west'][0,:,:]);  _=ax8.imshow(ncout['temp_east'][0,:,:])
# Out:
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-21T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-22T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-23T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-24T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_temp_2018-08-25T00:00:00Z.nc4

# %% [markdown]
# ## 3. ROMS 격자의 염분 경계장 만들기

# %%
dt = date_beg
while(dt <= date_end):
    ymdh = dt.strftime('%Y-%m-%dT%H:%M:%SZ')
    
    hycom_file = 'HYCOM/HYCOM4Soulik_ts3z_%s.nc4'%ymdh
    roms_file = 'ROMS/ROMS4%s_salt_%s.nc4'%(dst_name,ymdh)
    remapBC(hycom_file,'salinity', wts_file, src_grd, dst_grd3z, roms_file, verbose=False)
    
    dt += timedelta(hours=3*strideTime)

with Dataset(roms_file,'r') as ncout:
    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(2,4,1); ax2 = fig.add_subplot(2,4,2)
    ax3 = fig.add_subplot(2,4,3); ax4 = fig.add_subplot(2,4,4)
    _=ax1.plot(ncout['salt_south'][0,-1,:]); _=ax2.plot(ncout['salt_north'][0,-1,:])
    _=ax3.plot(ncout['salt_west'][0,-1,:]);  _=ax4.plot(ncout['salt_east'][0,-1,:])
    ax5 = fig.add_subplot(2,4,5); ax6 = fig.add_subplot(2,4,6)
    ax7 = fig.add_subplot(2,4,7); ax8 = fig.add_subplot(2,4,8)
    _=ax5.imshow(ncout['salt_south'][0,:,:]); _=ax6.imshow(ncout['salt_north'][0,:,:])
    _=ax7.imshow(ncout['salt_west'][0,:,:]);  _=ax8.imshow(ncout['salt_east'][0,:,:])
# Out:
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-21T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-22T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-23T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T00:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T03:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T06:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T09:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T12:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T15:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T18:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-24T21:00:00Z.nc4
# ==>Info: Creating file ROMS/ROMS4Soulik_salt_2018-08-25T00:00:00Z.nc4

# %% [markdown]
# ## 4. ROMS 격자의 UV 초기장 만들기

# %%
dt = date_beg
while(dt <= date_end):
    ymdh = dt.strftime('%Y-%m-%dT%H:%M:%SZ')
    
    hycom_fileuv = 'HYCOM/HYCOM4Soulik_uv3z_%s.nc4'%ymdh
    roms_fileuv = ['ROMS/ROMS4%s_u_%s.nc4'%(dst_name,ymdh),
                   'ROMS/ROMS4%s_v_%s.nc4'%(dst_name,ymdh)]
    remapBCuv(hycom_fileuv,['water_u','water_v'], wts_file, src_grd, dst_grd3z, roms_fileuv, verbose=False)
    
    dt += timedelta(hours=3*strideTime)
# Out:
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-21T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-21T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-22T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-22T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-23T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-23T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T03:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T06:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T09:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T12:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T15:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T18:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-24T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-24T21:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_u_2018-08-25T00:00:00Z.nc4
# ==>Info: Creating destination file ROMS/ROMS4Soulik_v_2018-08-25T00:00:00Z.nc4

# %%
with Dataset(roms_fileuv[0],'r') as ncout:
    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(2,4,1); ax2 = fig.add_subplot(2,4,2)
    ax3 = fig.add_subplot(2,4,3); ax4 = fig.add_subplot(2,4,4)
    _=ax1.plot(ncout['u_south'][0,-1,:]); _=ax2.plot(ncout['u_north'][0,-1,:])
    _=ax3.plot(ncout['u_west'][0,-1,:]);  _=ax4.plot(ncout['u_east'][0,-1,:])
    ax5 = fig.add_subplot(2,4,5); ax6 = fig.add_subplot(2,4,6)
    ax7 = fig.add_subplot(2,4,7); ax8 = fig.add_subplot(2,4,8)
    _=ax5.imshow(ncout['u_south'][0,:,:]); _=ax6.imshow(ncout['u_north'][0,:,:])
    _=ax7.imshow(ncout['u_west'][0,:,:]);  _=ax8.imshow(ncout['u_east'][0,:,:])

# %%
with Dataset(roms_fileuv[1],'r') as ncout:
    fig = plt.figure(figsize=(15,6))
    ax1 = fig.add_subplot(2,4,1); ax2 = fig.add_subplot(2,4,2)
    ax3 = fig.add_subplot(2,4,3); ax4 = fig.add_subplot(2,4,4)
    _=ax1.plot(ncout['v_south'][0,-1,:]); _=ax2.plot(ncout['v_north'][0,-1,:])
    _=ax3.plot(ncout['v_west'][0,-1,:]);  _=ax4.plot(ncout['v_east'][0,-1,:])
    ax5 = fig.add_subplot(2,4,5); ax6 = fig.add_subplot(2,4,6)
    ax7 = fig.add_subplot(2,4,7); ax8 = fig.add_subplot(2,4,8)
    _=ax5.imshow(ncout['v_south'][0,:,:]); _=ax6.imshow(ncout['v_north'][0,:,:])
    _=ax7.imshow(ncout['v_west'][0,:,:]);  _=ax8.imshow(ncout['v_east'][0,:,:])

# %% [markdown]
# ## 5. 경계장 합치기

# %%
# merge file
bc_file = 'ROMS4%s_bc.nc'%expname
if os.path.isfile(bc_file): os.remove(bc_file)

in_files = 'ROMS/ROMS4%s_ssh_*.nc4'%expname; merge_file = 'ROMS/ROMS4%s_ssh_bc.nc'%expname
subprocess.call('ncrcat %s %s'%(in_files,bc_file), shell=True)

in_files = 'ROMS/ROMS4%s_temp_*.nc4'%expname; merge_file = 'ROMS/ROMS4%s_temp_bc.nc'%expname
if os.path.isfile(merge_file): os.remove(merge_file)
subprocess.call('ncrcat %s %s'%(in_files,merge_file), shell=True)
subprocess.call('ncks -a -A %s %s'%(merge_file,bc_file), shell=True)

in_files = 'ROMS/ROMS4%s_salt_*.nc4'%expname; merge_file = 'ROMS/ROMS4%s_salt_bc.nc'%expname
if os.path.isfile(merge_file): os.remove(merge_file)
subprocess.call('ncrcat %s %s'%(in_files,merge_file), shell=True)
subprocess.call('ncks -a -A %s %s'%(merge_file,bc_file), shell=True)

in_files = 'ROMS/ROMS4%s_u_*.nc4'%expname; merge_file = 'ROMS/ROMS4%s_u_bc.nc'%expname
if os.path.isfile(merge_file): os.remove(merge_file)
subprocess.call('ncrcat %s %s'%(in_files,merge_file), shell=True)
subprocess.call('ncks -a -A %s %s'%(merge_file,bc_file), shell=True)

in_files = 'ROMS/ROMS4%s_v_*.nc4'%expname; merge_file = 'ROMS/ROMS4%s_v_bc.nc'%expname
if os.path.isfile(merge_file): os.remove(merge_file)
subprocess.call('ncrcat %s %s'%(in_files,merge_file), shell=True)
subprocess.call('ncks -a -A %s %s'%(merge_file,bc_file), shell=True)

print('==>Info: Creating final BC - %s'%bc_file)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# ==>Info: Creating final BC - ROMS4Soulik_bc.nc

# %%
fig = plt.figure(figsize=(12,2))
axE = fig.add_subplot(2,3,1); axT = fig.add_subplot(2,3,2); axS = fig.add_subplot(2,3,3)
axU = fig.add_subplot(2,3,5); axV = fig.add_subplot(2,3,6)

with Dataset(bc_file) as ncIC:
    _=axE.imshow(ncIC['zeta_south'][:,:])
    _=axT.imshow(ncIC['temp_south'][-1,:,:])
    _=axS.imshow(ncIC['salt_south'][-1,:,:])
    _=axU.imshow(ncIC['u_south'][-1,:,:])
    _=axV.imshow(ncIC['v_south'][-1,:,:])

# %%
fig = plt.figure(figsize=(12,2))
axE = fig.add_subplot(2,3,1); axT = fig.add_subplot(2,3,2); axS = fig.add_subplot(2,3,3)
axU = fig.add_subplot(2,3,5); axV = fig.add_subplot(2,3,6)

with Dataset(bc_file) as ncIC:
    _=axE.imshow(ncIC['zeta_north'][:,:])
    _=axT.imshow(ncIC['temp_north'][-1,:,:])
    _=axS.imshow(ncIC['salt_north'][-1,:,:])
    _=axU.imshow(ncIC['u_north'][-1,:,:])
    _=axV.imshow(ncIC['v_north'][-1,:,:])
